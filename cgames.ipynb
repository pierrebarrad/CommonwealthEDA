# %%
# import libraries

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
import plotly.express as px
import missingno as msno

# %%
# read file
part = pd.read_csv('/Users/mac/Desktop/Data Analysis/commonwealth games 2022 - players participated.csv')
print(part)
# Out:
#                     ATHLETE NAME\t           SPORT  GENDER   AGE       TEAM
# 0                         GregHire  3x3 Basketball    Male  34.0  Australia
# 1     Daniel Geoffrey CraigJohnson  3x3 Basketball    Male  34.0  Australia
# 2                  LaurenMansfield  3x3 Basketball  Female  32.0  Australia
# 3                     LaurenScherf  3x3 Basketball  Female  26.0  Australia
# 4                    JesseWagstaff  3x3 Basketball    Male  36.0  Australia
# ...                            ...             ...     ...   ...        ...
# 4528                      JohnVake       Wrestling    Male  31.0      Tonga
# 4529                   VeronicaAyo       Wrestling  Female  28.0     Uganda
# 4530                    JacobNtuyo       Wrestling    Male  28.0     Uganda
# 4531                   CurtisDodge       Wrestling    Male  29.0      Wales
# 4532                  ShannonHarry       Wrestling  Female  24.0      Wales
#
# [4533 rows x 5 columns]

# %%
part.head(20)
# Out:
#                   ATHLETE NAME\t           SPORT  GENDER   AGE  \
# 0                       GregHire  3x3 Basketball    Male  34.0
# 1   Daniel Geoffrey CraigJohnson  3x3 Basketball    Male  34.0
# 2                LaurenMansfield  3x3 Basketball  Female  32.0
# 3                   LaurenScherf  3x3 Basketball  Female  26.0
# 4                  JesseWagstaff  3x3 Basketball    Male  36.0
# 5                  MarenaWhittle  3x3 Basketball  Female  28.0
# 6                     AlexWilson  3x3 Basketball  Female  28.0
# 7                      TomWright  3x3 Basketball    Male  33.0
# 8                 ShauliquaFahie  3x3 Basketball  Female  21.0
# 9              MahkaylaPickering  3x3 Basketball  Female  22.0
# 10                KeithreceSmith  3x3 Basketball  Female  21.0
# 11                     JoyVictor  3x3 Basketball  Female  23.0
# 12                 BikramjitGill  3x3 Basketball    Male  30.0
# 13                    TayaHanson  3x3 Basketball  Female  22.0
# ...

# %%
part.tail(20)
# Out:
#                             ATHLETE NAME\t      SPORT  GENDER   AGE  \
# 4513                      Nicolaasde Lange  Wrestling    Male  20.0
# 4514                         EdwardLessing  Wrestling    Male  21.0
# 4515                       Jakobo TankiTau  Wrestling    Male  25.0
# 4516                          Arnovan Zijl  Wrestling    Male  20.0
# 4517      Chamodya KeshaniMaduravalage Don  Wrestling  Female  18.0
# 4518                     NethmiPoruthotage  Wrestling  Female  18.0
# 4519  Shriyanthika NiroshaniSinhala Pedige  Wrestling  Female  34.0
# 4520        SureshWarnakulasuriya Fernando  Wrestling    Male  33.0
# 4521                     SachiniWeraduwage  Wrestling  Female  26.0
# 4522                    ShanithYoda Pedige  Wrestling    Male  29.0
# 4523                        ThornDemeritte  Wrestling    Male  32.0
# 4524                          RashjiMackey  Wrestling    Male  36.0
# 4525              Tiger LilyCocker Lemalie  Wrestling  Female  18.0
# ...

# %%
# check columns
part.keys()
# Out:
# Index(['ATHLETE NAME\t', 'SPORT', 'GENDER', 'AGE', 'TEAM'], dtype='object')

# %%
# check data type
part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4533 entries, 0 to 4532
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ATHLETE NAME	  4533 non-null   object
#  1   SPORT          4533 non-null   object
#  2   GENDER         4533 non-null   object
#  3   AGE            4532 non-null   float64
#  4   TEAM           4533 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 177.2+ KB

# %%
# check missing values

part.isnull().sum()
# Out:
# ATHLETE NAME\t    0
# SPORT             0
# GENDER            0
# AGE               1
# TEAM              0
# dtype: int64

# %%
# SPORTS held by count
sp = part['SPORT'].value_counts()
print(sp)
# Out:
# Athletics and Para Athletics             902
# Aquatics - Swimming and Para Swimming    454
# Hockey                                   360
# Rugby Sevens                             314
# Cycling - Road                           290
# Boxing                                   241
# Lawn Bowls and Para Lawn Bowls           228
# Table Tennis and Para Table Tennis       191
# Weightlifting                            178
# Judo                                     160
# Badminton                                151
# Netball                                  144
# Wrestling                                121
# Triathlon and Para Triathlon             120
# Cricket T20                              120
# Squash                                   111
# Gymnastics - Artistic                    104
# Aquatics - Diving                         75
# 3x3 Basketball                            64
# Beach Volleyball                          48
# 3x3 Wheelchair Basketball                 47
# ...

# %%
# Treemap plot to show different types of sports

fig = px.treemap(part, path=['SPORT'], title='Treemap showing SPORTS by count')
fig.show()
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
part['GENDER'].value_counts()
# Out:
# Male      2401
# Female    2132
# Name: GENDER, dtype: int64

# %%
# countplot showing Gender


sns.countplot(x = part['GENDER'], palette='husl')
plt.title('Gender count by Volume')
plt.show()

# %%
part['TEAM'].value_counts()
# Out:
# England              437
# Australia            433
# Canada               268
# Scotland             261
# New Zealand          234
#                     ...
# Brunei Darussalam      7
# Kiribati               6
# St Kitts & Nevis       6
# Montserrat             5
# Tuvalu                 5
# Name: TEAM, Length: 72, dtype: int64

# %%
gtm = part.groupby(['GENDER', 'TEAM']).size()
print(gtm)
# Out:
# GENDER  SPORT
# Female  3x3 Basketball                            32
#         3x3 Wheelchair Basketball                 24
#         Aquatics - Diving                         37
#         Aquatics - Swimming and Para Swimming    204
#         Athletics and Para Athletics             409
#         Badminton                                 73
#         Beach Volleyball                          24
#         Boxing                                    61
#         Cricket T20                              120
#         Cycling - Road                           106
#         Cycling - Track and Para Track            16
#         Gymnastics - Artistic                     48
#         Gymnastics - Rhythmic                     29
#         Hockey                                   180
#         Judo                                      63
#         Lawn Bowls and Para Lawn Bowls           109
#         Netball                                  144
# ...

# %%
#Histogram showing distribution of Gender in relation to age

ig= px.histogram(x=part['AGE'], color=part['GENDER'], barmode='group')
fig.show()

# %%
#Treemap showing country participation

fig = px.treemap(part, path=['TEAM'], title='Sports by Value')
fig.show()
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
# finding how Sport and Age is related 
# ie for a sport what ages are engaged in that sport

sg = part.groupby(['SPORT', 'AGE']).size()
print(sg)
# Out:
# SPORT           AGE
# 3x3 Basketball  17.0    1
#                 19.0    2
#                 20.0    1
#                 21.0    6
#                 22.0    7
#                        ..
# Wrestling       34.0    3
#                 36.0    1
#                 37.0    1
#                 39.0    1
#                 44.0    1
# Length: 583, dtype: int64

# %%
# Histogram showing distrubution of Sports and Gender

fig= px.histogram(x=part['SPORT'].sort_values(ascending=False), color=part['GENDER'], barmode='group')
fig.show()

# %%
# Histogram showing distrubution of Sports and Countries
# ie what countries are engaged in what sports


fig= px.histogram(y=part['TEAM'].sort_values(ascending=False), color=part['SPORT'], barmode='stack',height=1200)
fig.show()

# %%
# Histogram showing distrubution of Sports and Gender

fig= px.histogram(y=part['TEAM'].sort_values(ascending=False), color=part['GENDER'], barmode='stack',height=1200)
fig.show()

# %%
# reading data of participants who won
# winners visualization
won = pd.read_csv('/Users/mac/Desktop/Data Analysis/commonwealth games 2022 - players won medals in cwg games 2022.csv')
print(won)
# Out:
#            ATHLETE NAME       TEAM                           SPORT  \
# 0          Aaron Wilson  Australia  Lawn Bowls and Para Lawn Bowls
# 1        Abbey Caldwell  Australia    Athletics and Para Athletics
# 2        Abigail Paduch  Australia                            Judo
# 3            Alana King  Australia                     Cricket T20
# 4         Aleisha Power  Australia                          Hockey
# ...                 ...        ...                             ...
# 1553       Taylor Bevan      Wales                          Boxing
# 1554    William Roberts      Wales  Cycling - Track and Para Track
# 1555   Muzala Samukonga     Zambia    Athletics and Para Athletics
# 1556  Patrick Chinyemba     Zambia                          Boxing
# 1557      Stephen Zimba     Zambia                          Boxing
#
#                                          EVENT MEDAL           CONTINENT  \
# 0                                Men's Singles     G  Australia& Oceania
# ...

# %%
won.head()
# Out:
#      ATHLETE NAME       TEAM                           SPORT          EVENT  \
# 0    Aaron Wilson  Australia  Lawn Bowls and Para Lawn Bowls  Men's Singles
# 1  Abbey Caldwell  Australia    Athletics and Para Athletics  Women's 1500m
# 2  Abigail Paduch  Australia                            Judo   Women +78 kg
# 3      Alana King  Australia                     Cricket T20    Cricket T20
# 4   Aleisha Power  Australia                          Hockey          Women
#
#   MEDAL           CONTINENT EVENT TYPE
# 0     G  Australia& Oceania     Single
# 1     B  Australia& Oceania     Single
# 2     B  Australia& Oceania     Single
# 3     G  Australia& Oceania      Mixed
# 4     S  Australia& Oceania      Mixed

# %%
won.tail()
# Out:
#            ATHLETE NAME    TEAM                           SPORT  \
# 1553       Taylor Bevan   Wales                          Boxing
# 1554    William Roberts   Wales  Cycling - Track and Para Track
# 1555   Muzala Samukonga  Zambia    Athletics and Para Athletics
# 1556  Patrick Chinyemba  Zambia                          Boxing
# 1557      Stephen Zimba  Zambia                          Boxing
#
#                                          EVENT MEDAL CONTINENT EVENT TYPE
# 1553  Men’s Over 75kg-80kg (Light Heavyweight)     S    Europe     Single
# 1554                   Men's 15km Scratch Race     B    Europe     Single
# 1555                                Men's 400m     G    Africa     Single
# 1556          Men’s Over 48kg-51kg (Flyweight)     B    Africa     Single
# 1557     Men’s Over 63.5kg-67kg (Welterweight)     S    Africa     Single

# %%
won.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558 entries, 0 to 1557
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ATHLETE NAME  1558 non-null   object
#  1   TEAM          1558 non-null   object
#  2   SPORT         1558 non-null   object
#  3   EVENT         1558 non-null   object
#  4   MEDAL         1558 non-null   object
#  5   CONTINENT     1558 non-null   object
#  6   EVENT TYPE    1558 non-null   object
# dtypes: object(7)
# memory usage: 85.3+ KB

# %%
#  check columns
won.keys()
# Out:
# Index(['ATHLETE NAME', 'TEAM', 'SPORT', 'EVENT', 'MEDAL', 'CONTINENT',
#        'EVENT TYPE'],
#       dtype='object')

# %%
# calculations
won.describe()
# Out:
#        ATHLETE NAME       TEAM                                  SPORT  EVENT  \
# count          1558       1558                                   1558   1558
# unique         1240         43                                     25    258
# top     Emma McKeon  Australia  Aquatics - Swimming and Para Swimming  Women
# freq              8        336                                    274    123
#
#        MEDAL           CONTINENT EVENT TYPE
# count   1558                1558       1558
# unique     3                   5          2
# top        B  Australia& Oceania      Mixed
# freq     543                 490        863

# %%
# checking for null values

won.isnull().sum()
# Out:
# ATHLETE NAME    0
# TEAM            0
# SPORT           0
# EVENT           0
# MEDAL           0
# CONTINENT       0
# EVENT TYPE      0
# dtype: int64

# %%
won['TEAM'].value_counts()
# Out:
# Australia             336
# England               327
# Canada                155
# India                 132
# New Zealand           116
# Scotland               72
# Malaysia               45
# South Africa           43
# Nigeria                43
# Wales                  40
# Jamaica                37
# Singapore              31
# Fiji                   28
# Kenya                  26
# Northern Ireland       21
# Cyprus                 15
# Trinidad & Tobago      15
# Pakistan                8
# Botswana                6
# Ghana                   5
# Uganda                  5
# Mauritius               5
# Samoa                   5
# Sri Lanka               4
# Namibia                 4
# Cameroon                4
# Zambia                  3
# Barbados                3
# Mozambique              3
# Tanzania                3
# Bermuda                 2
# Vanuatu                 2
# Guernsey                2
# Grenada                 2
# The Bahamas             2
# ...

# %%
won['SPORT'].value_counts()
# Out:
# Aquatics - Swimming and Para Swimming    274
# Athletics and Para Athletics             231
# Hockey                                   108
# Cycling - Track and Para Track            91
# Lawn Bowls and Para Lawn Bowls            84
# Rugby Sevens                              78
# Gymnastics - Artistic                     66
# Boxing                                    64
# Table Tennis and Para Table Tennis        60
# Judo                                      56
# Badminton                                 54
# Aquatics - Diving                         54
# Weightlifting                             48
# Wrestling                                 45
# Cricket T20                               45
# Netball                                   36
# 3x3 Basketball                            24
# Gymnastics - Rhythmic                     24
# Triathlon and Para Triathlon              24
# Squash                                    24
# 3x3 Wheelchair Basketball                 23
# ...

# %%
won['EVENT'].value_counts()
# Out:
# Women                              123
# Men                                122
# Cricket T20                         45
# Netball                             36
# Mixed Team Event                    30
#                                   ...
# Men's 50m Freestyle S7               3
# Men's Sprint                         3
# Men's Discus Throw F42-44/61-64      3
# Women's Freestyle 53 kg              2
# Women's T53/54 Marathon              2
# Name: EVENT, Length: 258, dtype: int64

# %%
won['EVENT TYPE'].value_counts()
# Out:
# Mixed     863
# Single    695
# Name: EVENT TYPE, dtype: int64

# %%
won['CONTINENT'].value_counts()
# Out:
# Australia& Oceania       490
# Europe                   478
# Asia                     220
# Caribbean & Americans    219
# Africa                   151
# Name: CONTINENT, dtype: int64

# %%
won['MEDAL'].value_counts()
# Out:
# B    543
# S    508
# G    507
# Name: MEDAL, dtype: int64

# %%
# bar graph showing number of medals won
sns.countplot(x = won['MEDAL'] , palette='mako')
plt.show()

# %%
# bar graph showing number of medals won

plt.figure(figsize=(15,10))
sns.countplot(x = won['CONTINENT'] , palette='mako')
plt.show()

# %%
fig = px.treemap(won, path=['SPORT'], title='Sports by Volume')
fig.show()
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fig= px.pie(won, names = 'EVENT TYPE', title='Pie chart showing Types of Events held')
fig.show()

# %%
# Distribution showing type of medals won and countries / team that won those medals

fig= px.histogram(y=won['TEAM'].sort_values(ascending=False), color=won['MEDAL'], barmode='stack',height=1000)
fig.show()

# %%
# Histogram showing sports that attracted medals
fig= px.histogram(x=won['SPORT'],color=won['MEDAL'], barmode='stack',height=1000)
fig.show()

# %%
fig = px.treemap(won, path=['TEAM'], title='Treemap showing number of medals Countries won')
fig.show()
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
